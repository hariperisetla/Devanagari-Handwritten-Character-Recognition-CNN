# %% [markdown]
# ## Checking for GPU

# %%
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please ensure you have installed TensorFlow correctly')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 2.1.0
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ## Creating the CNN model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Activation, Dropout, GlobalAveragePooling2D, \
    BatchNormalization, concatenate, AveragePooling2D
from keras.optimizers import Adam
import matplotlib.pyplot as plt


def conv_layer(conv_x, filters):
    conv_x = BatchNormalization()(conv_x)
    conv_x = Activation('relu')(conv_x)
    conv_x = Conv2D(filters, (3, 3), padding='same')(conv_x)
    conv_x = Dropout(0.25)(conv_x)

    return conv_x


def dense_block(block_x, filters, growth_rate, layers_in_block):
    for i in range(layers_in_block):
        each_layer = conv_layer(block_x, growth_rate)
        block_x = concatenate([block_x, each_layer], axis=-1)
        filters += growth_rate
   
    return block_x, filters


def transition_block(trans_x, tran_filters):
    trans_x = BatchNormalization()(trans_x)
    trans_x = Activation('relu')(trans_x)
    trans_x = Conv2D(tran_filters, (1, 1), padding='same')(trans_x)
    trans_x = AveragePooling2D((2, 2), strides=(2, 2))(trans_x)

    return trans_x, tran_filters


def dense_net(filters, growth_rate, classes, dense_block_size, layers_in_block):
    input_img = Input(shape=(32, 32, 3))
    x = Conv2D(32, (3, 3), padding='same')(input_img)
    
    dense_x = BatchNormalization()(x)
    dense_x = Activation('relu')(x)

    dense_x = MaxPooling2D((3, 3), padding='same')(dense_x)
    for block in range(dense_block_size - 1):
        dense_x, filters = dense_block(dense_x, filters, growth_rate, layers_in_block)
        dense_x, filters = transition_block(dense_x, filters)

    dense_x, filters = dense_block(dense_x, filters, growth_rate, layers_in_block)
    dense_x = BatchNormalization()(dense_x)
    dense_x = Activation('relu')(dense_x)
    dense_x = GlobalAveragePooling2D()(dense_x)

    #fdhdfh
    dense_x = Flatten()(dense_x)

    classifier.add(Dense(units = 128, activation = 'relu'))
    classifier.add(Dropout(.2))
    
    output = Dense(classes, activation='softmax')(dense_x)

    return Model(input_img, output)

# %%
from keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

from keras.utils import to_categorical

ImageFile.LOAD_TRUNCATED_IMAGES = True

train_datagen = ImageDataGenerator(rescale = 1/255, shear_range = .2, rotation_range = 25)
test_datagen = ImageDataGenerator(rescale = 1/255)

training_set = train_datagen.flow_from_directory('Dataset/Train', target_size = (32, 32), 
                                                 batch_size = 256, class_mode = 'categorical')
test_set = test_datagen.flow_from_directory('Dataset/Test', target_size = (32, 32), 
                                                 batch_size = 256, class_mode = 'categorical')
# Out:
# Found 46000 images belonging to 46 classes.
# Found 11500 images belonging to 46 classes.

# %%
dense_block_size = 3
layers_in_block = 4

growth_rate = 32
classes = 46
classifier = dense_net(growth_rate * 2, growth_rate, classes, dense_block_size, layers_in_block)
classifier.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 11, 11, 32)   128         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 11, 11, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 11, 11, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 11, 11, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 11, 11, 64)   0           max_pooling2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 11, 11, 64)   256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 11, 11, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 11, 11, 32)   18464       activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 11, 11, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 11, 11, 96)   0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 11, 11, 96)   384         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 11, 11, 96)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 11, 11, 32)   27680       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 11, 11, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 11, 11, 128)  0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 11, 11, 128)  512         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 11, 11, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 11, 11, 32)   36896       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 11, 11, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 11, 11, 160)  0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 160)  640         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 11, 11, 160)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 11, 11, 192)  30912       activation_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 5, 5, 192)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 5, 5, 192)    768         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 5, 5, 192)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 5, 5, 32)     55328       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 5, 5, 32)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 5, 5, 224)    0           average_pooling2d_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 5, 5, 224)    896         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 224)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 5, 5, 32)     64544       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 5, 5, 32)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 5, 5, 256)    0           concatenate_5[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 5, 5, 256)    1024        concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 5, 5, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 5, 5, 32)     73760       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 5, 5, 32)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 5, 5, 288)    0           concatenate_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 5, 5, 288)    1152        concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 5, 5, 288)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 5, 5, 32)     82976       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 5, 5, 32)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 5, 5, 320)    0           concatenate_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 5, 5, 320)    1280        concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 5, 5, 320)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 5, 5, 320)    102720      activation_11[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 320)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2, 2, 320)    1280        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2, 2, 320)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 2, 32)     92192       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 2, 2, 32)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 2, 2, 352)    0           average_pooling2d_2[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 2, 2, 352)    1408        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2, 2, 352)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 2, 2, 32)     101408      activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 2, 2, 32)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 2, 2, 384)    0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 384)    1536        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 384)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 2, 2, 32)     110624      activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 2, 2, 32)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 2, 2, 416)    0           concatenate_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 416)    1664        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 416)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 32)     119840      activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 2, 2, 32)     0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 2, 2, 448)    0           concatenate_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 448)    1792        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 448)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 448)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 46)           20654       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 962,862
# Trainable params: 955,502
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
epochs = 25
optimizer = 'adam'
classifier.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])
history = classifier.fit(training_set, epochs=epochs, shuffle=True, validation_data=test_set)
# Out:
# Epoch 1/25
# 180/180 [==============================] - 43s 238ms/step - loss: 0.8826 - accuracy: 0.7997 - val_loss: 5.2905 - val_accuracy: 0.0404
# Epoch 2/25
# 180/180 [==============================] - 36s 200ms/step - loss: 0.1399 - accuracy: 0.9665 - val_loss: 1.5126 - val_accuracy: 0.5747
# Epoch 3/25
# 180/180 [==============================] - 33s 185ms/step - loss: 0.0932 - accuracy: 0.9755 - val_loss: 0.6579 - val_accuracy: 0.8262
# Epoch 4/25
# 180/180 [==============================] - 31s 173ms/step - loss: 0.0694 - accuracy: 0.9811 - val_loss: 1.7745 - val_accuracy: 0.5997
# Epoch 5/25
# 180/180 [==============================] - 30s 168ms/step - loss: 0.0594 - accuracy: 0.9840 - val_loss: 0.9357 - val_accuracy: 0.7878
# Epoch 6/25
# 180/180 [==============================] - 30s 168ms/step - loss: 0.0519 - accuracy: 0.9852 - val_loss: 0.7610 - val_accuracy: 0.7828
# Epoch 7/25
# 180/180 [==============================] - 31s 169ms/step - loss: 0.0453 - accuracy: 0.9866 - val_loss: 0.8572 - val_accuracy: 0.7868
# Epoch 8/25
# 180/180 [==============================] - 30s 168ms/step - loss: 0.0409 - accuracy: 0.9879 - val_loss: 0.8102 - val_accuracy: 0.8129
# Epoch 9/25
# 180/180 [==============================] - 30s 167ms/step - loss: 0.0391 - accuracy: 0.9882 - val_loss: 1.2676 - val_accuracy: 0.7563
# Epoch 10/25
#  86/180 [=============>................] - ETA: 13s - loss: 0.0348 - accuracy: 0.9897

# %%
import matplotlib.pyplot as plt

scores = classifier.evaluate(training_set)
print(scores)
print("Accuracy: %.2f%%" % (scores[1]*100))

# %% [markdown]
# ## Fitting the CNN model to the Dataset

# %%
classifier_json = classifier.to_json()

# with open("CNN_DevanagariHandWrittenCharacterRecognition.json", "w") as json_file:
#     json_file.write(model_json)
    
classifier.save_weights("CNN_DevanagariHandWrittenCharacterRecognition.h5")
print('Saved model to disk')

# %%
training_set.class_indices

# %% [markdown]
# ## Accuracy

# %% [markdown]
# ## Saving the model

# %% [markdown]
# ## Checking the data labels predicted

# %% [markdown]
# ## Creating a graphical user interface to draw the character

# %%
import PIL
from PIL import ImageTk, ImageDraw, Image, ImageOps
from tkinter import *
from keras.preprocessing import image
import os

# %%
def determine_character(res,acc):
    print(res)
    if res == 0:
        print('prediction : क')
        character.configure(text= 'क,')
        accuracy.configure(text=str(acc) + '%')
    elif res == 1:
        print('prediction : ख')
        character.configure(text= 'ख,')
        accuracy.configure(text=str(acc) + '%')
    
    elif res == 2:
        print('prediction : ग')
        character.configure(text= 'ग,')
        accuracy.configure(text=str(acc) + '%')
    
    elif res == 3:
        print('prediction : घ')
        character.configure(text= 'घ,')
        accuracy.configure(text=str(acc) + '%')        

    elif res == 4:
        print('prediction : ङ')
        character.configure(text= 'ङ,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 5:
        print('prediction : च')
        character.configure(text= 'च,')
        accuracy.configure(text=str(acc) + '%')
    
    elif res == 6:
        print('prediction : छ')
        character.configure(text= 'छ,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 7:
        print('prediction : ज')
        character.configure(text= 'ज,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 8:
        print('prediction : झ')
        character.configure(text= 'झ,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 9:
        print('prediction : ञ')
        character.configure(text= 'ञ,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 10:
        print('prediction : ट')
        character.configure(text= 'ट,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 11:
        print('prediction : ठ')
        character.configure(text= 'ठ,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 12:
        print('prediction : ड')
        character.configure(text= 'ड,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 13:
        print('prediction : ढ')
        character.configure(text= 'ढ,')
        accuracy.configure(text=str(acc) + '%')    
    
    elif res == 14:
        print('prediction : ण')
        character.configure(text= 'ण,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 15:
        print('prediction : त')
        character.configure(text= 'त,')
        accuracy.configure(text=str(acc) + '%')
        
    elif res == 16:
        print('prediction : थ')
        character.configure(text= 'थ,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 17:
        print('prediction : द')
        character.configure(text= 'द,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 18:
        print('prediction : ध')
        character.configure(text= 'ध,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 19:
        print('prediction : न')
        character.configure(text= 'न,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 20:
        print('prediction : प')
        character.configure(text= 'प,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 21:
        print('prediction : फ')
        character.configure(text= 'फ,')
        accuracy.configure(text=str(acc) + '%')        
        
    elif res == 22:
        print('prediction : ब')
        character.configure(text= 'ब,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 23:
        print('prediction : भ')
        character.configure(text= 'भ,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 24:
        print('prediction : म')
        character.configure(text= 'म,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 25:
        print('prediction : य')
        character.configure(text= 'य,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 26:
        print('prediction : र')
        character.configure(text= 'र,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 27:
        print('prediction : ल')
        character.configure(text= 'ल,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 28:
        print('prediction : व')
        character.configure(text= 'व,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 29:
        print('prediction : श')
        character.configure(text= 'श,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 30:
        print('prediction : ष')
        character.configure(text= 'ष,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 31:
        print('prediction : स')
        character.configure(text= 'स,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 32:
        print('prediction : ह')
        character.configure(text= 'ह,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 33:
        print('prediction : क्ष')
        character.configure(text= 'क्ष,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 34:
        print('prediction : त्र')
        character.configure(text= 'त्र,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 35:
        print('prediction : ज्ञ')
        character.configure(text= 'ज्ञ,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 36:
        print('prediction : ०')
        character.configure(text= '०,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 37:
        print('prediction : १')
        character.configure(text= '१,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 38:
        print('prediction : २')
        character.configure(text= '२,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 39:
        print('prediction : ३')
        character.configure(text= '३,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 40:
        print('prediction : ४')
        character.configure(text= '४,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 41:
        print('prediction : ५')
        character.configure(text= '५,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 42:
        print('prediction : ६')
        character.configure(text= '६,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 43:
        print('prediction : ७')
        character.configure(text= '७,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 44:
        print('prediction : ८')
        character.configure(text= '८,')
        accuracy.configure(text=str(acc) + '%')           
        
    elif res == 45:
        print('prediction : ९')
        character.configure(text= '९,')
        accuracy.configure(text=str(acc) + '%')

# %% [markdown]
# # GUI Application Final

# %%
# Final Application GUI
import numpy as np
import matplotlib.pyplot as plt
from tkinter import *
import tkinter as tk
# loading Python Imaging Library 
from PIL import ImageTk, Image 
from keras.models import load_model

# To get the dialog box to open when required 
from tkinter import filedialog 

classifier.load_weights('CNN_DevanagariHandWrittenCharacterRecognition.h5')

def single_prediction(test_img):
    
    test_img_arr = image.img_to_array(test_img)
    
    test_img_arr = np.expand_dims(test_img_arr, axis = 0)
#     accuracy = classifier.predict(test_img_arr)[0]
    prediction = classifier.predict(test_img_arr)
    
    result = np.argmax(prediction[0])
    acc = round(prediction[0][np.argmax(prediction[0])]*100,3)
    print(acc)
    res = classifier.predict([test_img_arr])[0]
    
    print(res, np.argmax(res), max(res))
    determine_character(result, str(acc))
    
def model():
    accuracy.configure(text="Predicting...")
    test_img = image.load_img('C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/image.jpg', target_size = (32, 32, 3))
    single_prediction(test_img)
    plt.imshow(test_img)

def delete_created_image():
    os.remove('C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/image.jpg')

def clear():
    delete_created_image()
    path = "C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/placeholder.jpg"
    img = Image.open(path) 
    img = img.resize((300, 300), Image.ANTIALIAS)
    img = ImageTk.PhotoImage(img) 
    panel = Label(root, image = img) 

    # set the image as img  
    panel.image = img 
    panel.grid(row = 1, pady=5, padx=5)
    character.configure(text="")
    accuracy.configure(text="Upload")
    
def open_img(): 
    # Select the Imagename  from a folder  
    x = openfilename() 
    print(x)
    # opens the image 
    img = Image.open(x) 
      
    # resize the image and apply a high-quality down sampling filter 
    img = img.resize((300, 300), Image.ANTIALIAS)
    
    #img = ImageOps.invert(img)
    filename = 'C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/image.jpg'
    img.save(filename)
    # PhotoImage class is used to add image to widgets, icons etc 
    img = ImageTk.PhotoImage(img) 
    
 
    panel = Label(root, image = img) 
      
    # set the image as img  
    panel.image = img 
    panel.grid(row = 1, pady=5, padx=5)

def openfilename(): 
  
    # open file dialog box to select image 
    filename = filedialog.askopenfilename(title ='Upload Image') 
    return filename 
    
# Create a windoe 
root = Tk() 

# Set Title as Image Loader 
root.title("Devanagari Character Recognition") 
root.resizable(0,0)
# Set the resolution of window 
root.geometry("700x450+400+150") 
root['bg'] = '#000'

path = "C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/placeholder.jpg"
img = Image.open(path) 
img = img.resize((300, 300), Image.ANTIALIAS)
img = ImageTk.PhotoImage(img) 
panel = Label(root, image = img) 

# set the image as img  
panel.image = img 
panel.grid(row = 1, pady=5, padx=5)

icon = PhotoImage(file = "C:/Users/peris/Documents/Devanagari Character Recognition - 2020/Dataset/SinglePrediction/icon.png") 
  
# Setting icon of master window 
root.iconphoto(False, icon) 


character = tk.Label(root, text="", font=("Helvetica", 70), bg="black", fg="white")
character.grid(row=1, column=2,pady=2, padx=2)
accuracy = tk.Label(root, text="     Upload     ", font=("Helvetica", 38), bg="black", fg="white")
accuracy.grid(row=1, column=5,pady=2, padx=2)

btnPredict=tk.Button(text="Predict",command=model, height=2, width=30, relief=GROOVE, bg="white", fg="black")

btnPredict.grid(row=3, column=5, pady=2, padx=5)

btnClear=tk.Button(text="Clear",command=clear, height=2, width=30, relief=GROOVE, bg="white", fg="black")
btnClear.grid(row=3, column=0, pady=2)

btn = Button(root, text ='Open Image', command = open_img, pady=2, padx=2, height=2, width=30, relief=GROOVE, bg="white", fg="black").grid(row = 0, columnspan = 4) 

root.mainloop()
